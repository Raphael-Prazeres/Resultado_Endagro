# %%
import tabula
import pandas as pd

# %% [markdown]
# # Teste

# %%
lista_tabelas = tabula.read_pdf("C:/Users/rpraz/OneDrive/Área de Trabalho/Endagro/anexo-ed-resultado-objetiva-emdagro.pdf", pages="all")
lista_tabelas[0]

# %%
tabela = lista_tabelas[0]
#tabela.columns = ['nome','inscricao','portugues','nrle','informatica','geografia','especifico','nota_objetiva']
tabela = tabela[2:]
tabela.columns = ['name','notas','especifico','nota_objetiva']
tabela[['portugues','nrle','informatica','geografia']] = tabela["notas"].str.split(" ", expand=True)
tabela[['nome', 'inscricao']] = tabela['name'].str.rsplit(" ",n=1, expand=True)
tabela = tabela.drop(['name', 'notas'], axis=1)
tabela = tabela[['nome','inscricao','portugues','nrle','informatica','geografia','especifico','nota_objetiva']]
tabela = tabela.drop(2)

display(tabela)

# %%
tabela.set_index('nome')

# %% [markdown]
# # Correto

# %%
lista_tabelas = tabula.read_pdf("C:/Users/rpraz/OneDrive/Área de Trabalho/Endagro/anexo-ed-resultado-objetiva-emdagro.pdf", pages="all", lattice=True)
tecnico = lista_tabelas[0]
tecnico.columns = tecnico.iloc[0]
tecnico = tecnico.drop(0)
tecnico.head(2)
# Out:
# 0                             Nome   Inscrição Língua\rPortuguesa  \
# 1  Adolfo Jose Ferreira Dos Santos  2980002692               3.00
# 2         Adriano Barbosa Ferreira  2980002736               3.00
#
# 0 Noções de\rRaciocínio\rLógico e\rEstatística Noções de\rInformática  \
# 1                                         1.00                   1.00
# 2                                         1.00                   2.00
#
# 0 Geografia\rdo\rEstado de\rSergipe Conhecimento\rEspecífico  \
# 1                              8.00                    54.00
# 2                              4.00                    58.00
#
# 0 Nota da\rProva\rObjetiva
# 1                    67.00
# 2                    68.00

# %%
lista_tabelas1 = tabula.read_pdf("C:/Users/rpraz/OneDrive/Área de Trabalho/Endagro/anexo-ed-resultado-objetiva-emdagro.pdf", pages="all", lattice=True)
tecnico1 = lista_tabelas1[1]
tecnico1.loc[0] = tecnico1.columns
tecnico1.columns = tecnico.columns

tecnico1.head(2)
# Out:
# 0                      Nome   Inscrição Língua\rPortuguesa  \
# 0   Celso De Carvalho Gomes  2980002948               6.00
# 1  Cleyton Silva Dos Santos  2980003209                3.0
#
# 0 Noções de\rRaciocínio\rLógico e\rEstatística Noções de\rInformática  \
# 0                                         1.00                 1.00.1
# 1                                          3.0                    3.0
#
# 0 Geografia\rdo\rEstado de\rSergipe Conhecimento\rEspecífico  \
# 0                              2.00                    54.00
# 1                               4.0                     56.0
#
# 0 Nota da\rProva\rObjetiva
# 0                    64.00
# 1                     69.0

# %%
lista_tabelas2 = tabula.read_pdf("C:/Users/rpraz/OneDrive/Área de Trabalho/Endagro/anexo-ed-resultado-objetiva-emdagro.pdf", pages="all", lattice=True)
tecnico2 = lista_tabelas2[2]
tecnico2.loc[0] = tecnico2.columns
tecnico2.columns = tecnico.columns

tecnico2
# Out:
# 0                                Nome   Inscrição Língua\rPortuguesa  \
# 0            Geyzon Joaquim Gonçalves  2980004244               7.00
# 1           Gicelio De Oliveira Silva  2980003222                4.0
# 2         Gilcimar Jesus Das Candeias  2980001569                4.0
# 3         Gino Francisco De Lima Neto  2980004821                5.0
# 4          Giovaldo Castro Bala Filho  2980000038                2.0
# 5          Gleicianny De Brito Santos  2980004305                5.0
# 6                 Heldo De Lima Souza  2980000274                3.0
# 7     Ismael Fabio Almeida De Santana  2980003038                3.0
# 8               Italo Cintra Ferreira  2980001806                5.0
# 9                  Italo Santos Rocha  2980003788                3.0
# 10           Itamar De Souza Oliveira  2980003846                5.0
# 11   Jacqueline Alves Borges Ferreira  2980001482                4.0
# 12                 Jadison Dos Santos  2980002645                4.0
# ...

# %%
lista_tabelas3 = tabula.read_pdf("C:/Users/rpraz/OneDrive/Área de Trabalho/Endagro/anexo-ed-resultado-objetiva-emdagro.pdf", pages="all", lattice=True)
tecnico3 = lista_tabelas3[3]
tecnico3.loc[0] = tecnico3.columns
tecnico3.columns = tecnico.columns

tecnico3
# Out:
# 0                                      Nome   Inscrição Língua\rPortuguesa  \
# 0               José Reginaldo Matos Dantas  2980002193               2.00
# 1               José Uilson De Jesus Santos  2980003062                2.0
# 2                     Josevânia De Oliveira  2980002902                7.0
# 3                     Joyce Naiara Da Silva  2980003016                6.0
# 4                 Juan Ribeiro Melo Santana  2980004713                5.0
# 5                   Julio Cesar Silva Souza  2980000631                4.0
# 6          Kaoue Pinheiro Gonzaga De\rSouza  2980004629                4.0
# 7                     Kauan Mattos Ferreira  2980004689                2.0
# 8                 Lanielle Amarante Santana  2980003310                6.0
# 9                      Layra Oliveira Silva  2980001755                4.0
# 10         Leandro Marciel Ribeiro De Souza  2980000472                5.0
# ...

# %%
lista_tabelas4 = tabula.read_pdf("C:/Users/rpraz/OneDrive/Área de Trabalho/Endagro/anexo-ed-resultado-objetiva-emdagro.pdf", pages="all", lattice=True)
tecnico4 = lista_tabelas4[4]
tecnico4.loc[0] = tecnico4.columns
tecnico4.columns = tecnico.columns

tecnico4
# Out:
# 0                                       Nome   Inscrição Língua\rPortuguesa  \
# 0         Mayra Rodrigues Viturino\rBernardo  2980000258               6.00
# 1                  Miqueias Teixeira Batista  2980001216                3.0
# 2                   Mirelle Dos Santos Alves  2980002599                5.0
# 3                   Murillo Dos Santos Teles  2980000419                7.0
# 4                   Neide Ribeiro Dos Santos  2980004037                5.0
# 5                       Paulo Andrew Caetano  2980005303                2.0
# 6                             Paulo Henrique  2980001519                4.0
# 7              Paulo Sergio De Araujo Santos  2980003816                4.0
# 8   Pedro Átila Da Silva Maranduba\rDe Sousa  2980004293                4.0
# 9                      Pedro Queiroz De Lima  2980004143                3.0
# 10                Queni Dos Santos Gonçalves  2980000686                5.0
# ...

# %%
lista_tabelas5 = tabula.read_pdf("C:/Users/rpraz/OneDrive/Área de Trabalho/Endagro/anexo-ed-resultado-objetiva-emdagro.pdf", pages="all", lattice=True)
tecnico5 = lista_tabelas5[5]
tecnico5.loc[0] = tecnico5.columns
tecnico5.columns = tecnico.columns
tecnico5 = tecnico5[0:21]

tecnico5
# Out:
# 0                                   Nome   Inscrição Língua\rPortuguesa  \
# 0                 Thayná Da Cunha Santos  2980002984               6.00
# 1                  Thiago Costa Ferreira  2980000086               4.00
# 2                Tiago Da Silva Trindade  2980000560               5.00
# 3                   Uala Machado De Gois  2980004935               4.00
# 4         Uillizana De Caravalho Santana  2980002888               2.00
# 5           Ulemberg Belarminio De Sousa  2980000688               6.00
# 6           Valdenberg Jesus De Oliveira  2980000287               3.00
# 7                 Valdson Da Silva Costa  2980001401               4.00
# 8                  Valmir Oliveira Lopes  2980002774               6.00
# 9           Valterclecio Pereira Santana  2980003539               4.00
# 10      Vanilson Félix Dos Santos Júnior  2980005166               5.00
# 11             Vitória Coutinho Trindade  2980002659               5.00
# ...

# %%
tecnicos = pd.concat([tecnico, tecnico1, tecnico2, tecnico3, tecnico4, tecnico5])
tecnicos
# Out:
# 0                                     Nome   Inscrição Língua\rPortuguesa  \
# 1          Adolfo Jose Ferreira Dos Santos  2980002692               3.00
# 2                 Adriano Barbosa Ferreira  2980002736               3.00
# 3                     Afonso Alves Santana  2980003073               3.00
# 4   Alberto Ferreira Do Nascimento\rJunior  2980004263               4.00
# 5               Alciberto Valenca Coutinho  2980002399               2.00
# ..                                     ...         ...                ...
# 16    Wilker Dhenison Barbosa De\rOliveira  2980001125               4.00
# 17                      Willian Dos Santos  2980004656               1.00
# 18                   Xerxes Santos Furtado  2980000182               4.00
# 19                  Yan Dos Santos Cardoso  2980001110               7.00
# 20              Zenaide Caetano Dos Santos  2980002538               4.00
#
# 0  Noções de\rRaciocínio\rLógico e\rEstatística Noções de\rInformática  \
# ...
